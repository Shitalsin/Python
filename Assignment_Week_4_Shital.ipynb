# %% [markdown]
# <a href="https://colab.research.google.com/github/Shitalsin/Python/blob/main/Assignment_Week_4_Shital.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 CIFAR-10 Image Classification Learning Project
# ## Build and Compare **ANN vs CNN** on CIFAR-10
#
# This notebook is designed for **students and beginners** to learn:
# - How image classification works
# - Why **CNN performs better than ANN**
# - How architecture impacts performance
# - How training strategies improve results
#
# 🎯 **Learning Goal:** Understand the complete DL pipeline by **reading the markdown + running the ready code**.

# %% [markdown]
# # 🧠 Problem Statement
# Build an image classification model on the **CIFAR-10 dataset** using:
#
# 1. **Artificial Neural Network (ANN)**
# 2. **Convolutional Neural Network (CNN)**
#
# Then compare:
# - Accuracy
# - Loss curves
# - Generalization
# - Training strategies (dropout, batch norm, augmentation)
#
# ---
# ### 📦 CIFAR-10 Classes
# Airplane, Automobile, Bird, Cat, Deer, Dog, Frog, Horse, Ship, Truck

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.20.0

# %% [markdown]
# # 📥 Load Dataset
# We use **CIFAR-10**, which contains **60,000 color images of size 32×32×3**.
# - 50,000 training images
# - 10,000 test images

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

print("Train shape:", x_train.shape)
print("Test shape:", x_test.shape)
# Out:
# Train shape: (50000, 32, 32, 3)
# Test shape: (10000, 32, 32, 3)

# %% [markdown]
# ## 🖼️ Visualize Sample Images

# %%
plt.figure(figsize=(10,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 🧹 Preprocessing
# We normalize pixel values from **0–255 → 0–1** so training becomes stable.

# %%
x_train_norm = x_train / 255.0
x_test_norm = x_test / 255.0

x_train_flat = x_train_norm.reshape(len(x_train_norm), -1)
x_test_flat = x_test_norm.reshape(len(x_test_norm), -1)

# %% [markdown]
# # 🔹 Part 1: ANN Model
# ANN treats images as **flat vectors**, so it cannot preserve spatial features.
# This helps students understand **why CNN is better for images**.

# %%
ann_model = models.Sequential([
    layers.Dense(512, activation='relu', input_shape=(3072,)),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.Dense(10, activation='softmax')
])

ann_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

ann_history = ann_model.fit(
    x_train_flat, y_train,
    epochs=10,
    validation_split=0.1,
    batch_size=64
)
# Out:
# Epoch 1/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.2631 - loss: 2.0029 - val_accuracy: 0.3098 - val_loss: 1.8609
# Epoch 2/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.3100 - loss: 1.8821 - val_accuracy: 0.3500 - val_loss: 1.8057
# Epoch 3/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 41s 29ms/step - accuracy: 0.3336 - loss: 1.8304 - val_accuracy: 0.3578 - val_loss: 1.7873
# Epoch 4/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.3478 - loss: 1.7944 - val_accuracy: 0.3800 - val_loss: 1.7483
# Epoch 5/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 40s 29ms/step - accuracy: 0.3585 - loss: 1.7616 - val_accuracy: 0.4122 - val_loss: 1.6939
# Epoch 6/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 21s 30ms/step - accuracy: 0.3650 - loss: 1.7477 - val_accuracy: 0.4094 - val_loss: 1.6899
# Epoch 7/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.3698 - loss: 1.7313 - val_accuracy: 0.4182 - val_loss: 1.6751
# Epoch 8/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.3772 - loss: 1.7165 - val_accuracy: 0.3992 - val_loss: 1.6887
# Epoch 9/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.3823 - loss: 1.7076 - val_accuracy: 0.4132 - val_loss: 1.6798
# Epoch 10/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.3869 - loss: 1.6953 - val_accuracy: 0.4130 - val_loss: 1.6686

# %%
ann_test_loss, ann_test_acc = ann_model.evaluate(x_test_flat, y_test)
print("ANN Test Accuracy:", ann_test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4314 - loss: 1.6195
# ANN Test Accuracy: 0.43140000104904175

# %% [markdown]
# # 🔹 Part 2: CNN Model
# CNN preserves **spatial relationships** using:
# - Convolution layers
# - Pooling
# - Feature extraction
# - Hierarchical learning
#
# This is why CNN performs much better for image tasks.

# %%
cnn_model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), activation='relu'),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

cnn_history = cnn_model.fit(
    x_train_norm, y_train,
    epochs=10,
    validation_split=0.1,
    batch_size=64
)
# Out:
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 82s 71ms/step - accuracy: 0.7091 - loss: 0.8339 - val_accuracy: 0.6848 - val_loss: 0.9140
# Epoch 5/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 51s 73ms/step - accuracy: 0.7389 - loss: 0.7437 - val_accuracy: 0.6632 - val_loss: 0.9877
# Epoch 6/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 48s 69ms/step - accuracy: 0.7693 - loss: 0.6562 - val_accuracy: 0.7200 - val_loss: 0.8386
# Epoch 7/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 48s 69ms/step - accuracy: 0.7911 - loss: 0.5916 - val_accuracy: 0.6588 - val_loss: 1.0676
# Epoch 8/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 49s 70ms/step - accuracy: 0.8095 - loss: 0.5401 - val_accuracy: 0.6936 - val_loss: 0.9570
# Epoch 9/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 82s 70ms/step - accuracy: 0.8322 - loss: 0.4724 - val_accuracy: 0.7392 - val_loss: 0.8522
# Epoch 10/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 48s 69ms/step - accuracy: 0.8442 - loss: 0.4348 - val_accuracy: 0.7066 - val_loss: 1.0162
# Epoch 1/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 51s 69ms/step - accuracy: 0.4714 - loss: 1.4824 - val_accuracy: 0.4880 - val_loss: 1.4862
# Epoch 2/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 82s 69ms/step - accuracy: 0.6064 - loss: 1.1245 - val_accuracy: 0.5840 - val_loss: 1.2449
# Epoch 3/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 83s 70ms/step - accuracy: 0.6639 - loss: 0.9690 - val_accuracy: 0.6616 - val_loss: 0.9726
# Epoch 4/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 49s 70ms/step - accuracy: 0.7038 - loss: 0.8551 - val_accuracy: 0.6550 - val_loss: 0.9930
# Epoch 5/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 81s 69ms/step - accuracy: 0.7344 - loss: 0.7606 - val_accuracy: 0.6068 - val_loss: 1.2513
# Epoch 6/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 50s 71ms/step - accuracy: 0.7594 - loss: 0.6869 - val_accuracy: 0.7092 - val_loss: 0.8539
# Epoch 7/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 50s 71ms/step - accuracy: 0.7842 - loss: 0.6194 - val_accuracy: 0.6268 - val_loss: 1.1176
# Epoch 8/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 80s 68ms/step - accuracy: 0.8002 - loss: 0.5635 - val_accuracy: 0.6992 - val_loss: 0.9535
# Epoch 9/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 49s 69ms/step - accuracy: 0.8218 - loss: 0.5037 - val_accuracy: 0.7194 - val_loss: 0.9344
# Epoch 10/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 79s 66ms/step - accuracy: 0.8360 - loss: 0.4626 - val_accuracy: 0.6962 - val_loss: 0.9357

# %%
cnn_test_loss, cnn_test_acc = cnn_model.evaluate(x_test_norm, y_test)
print("CNN Test Accuracy:", cnn_test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6857 - loss: 0.9893
# CNN Test Accuracy: 0.685699999332428

# %% [markdown]
# ## 📈 Compare Learning Curves

# %%
plt.figure(figsize=(10,4))
plt.plot(ann_history.history['val_accuracy'], label='ANN Val Acc')
plt.plot(cnn_history.history['val_accuracy'], label='CNN Val Acc')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("ANN vs CNN Validation Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# # 🚀 Training Strategy Upgrade: Data Augmentation
# This strategy improves generalization by generating transformed images.

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])

aug_cnn_model = models.Sequential([
    data_augmentation,
    layers.Conv2D(32, 3, activation='relu', input_shape=(32,32,3)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

aug_cnn_model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

# Suggested optional run:
# aug_history = aug_cnn_model.fit(x_train_norm, y_train, epochs=10, validation_split=0.1)

# %% [markdown]
# # 📊 Final Comparison Table

# %%
comparison = pd.DataFrame({
    "Model": ["ANN", "CNN"],
    "Test Accuracy": [ann_test_acc, cnn_test_acc]
})
comparison
# Out:
#   Model  Test Accuracy
# 0   ANN         0.4314
# 1   CNN         0.6857

# %% [markdown]
# # 🎓 Student Learning Tasks
# Try these tasks after understanding the notebook:
#
# ### ✅ Beginner Tasks
# 1. Increase ANN layers and observe performance
# 2. Change CNN filters from 32→64→128
# 3. Increase epochs to 20
# 4. Add **EarlyStopping**
# 5. Add **data augmentation training**

# %% [markdown]
# # ✅ Conclusion
# - **ANN works**, but ignores image structure
# - **CNN extracts spatial features**, so it performs significantly better
# - **Training strategies** like dropout, batch norm, and augmentation improve results
# - This project builds strong fundamentals for **computer vision interviews and deep learning projects**

# %% [markdown]
# Experiment1: ANN with More Hidden Layers

# %%
ann_model_new = models.Sequential([
    layers.Dense(512, activation='relu', input_shape=(3072,)),
    layers.Dropout(0.3),

    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),

    layers.Dense(128, activation='relu'),

    layers.Dense(64, activation='relu'),

    layers.Dense(10, activation='softmax')
])

ann_model_new.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

ann_history_new = ann_model_new.fit(
    x_train_flat,
    y_train,
    epochs=10,
    validation_split=0.1,
    batch_size=64
)
# Out:
# Epoch 1/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 23s 30ms/step - accuracy: 0.2416 - loss: 2.0332 - val_accuracy: 0.3142 - val_loss: 1.8782
# Epoch 2/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.3065 - loss: 1.8918 - val_accuracy: 0.3574 - val_loss: 1.8012
# Epoch 3/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - accuracy: 0.3234 - loss: 1.8468 - val_accuracy: 0.3450 - val_loss: 1.7992
# Epoch 4/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 42s 32ms/step - accuracy: 0.3323 - loss: 1.8221 - val_accuracy: 0.3812 - val_loss: 1.7490
# Epoch 5/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - accuracy: 0.3434 - loss: 1.7979 - val_accuracy: 0.3754 - val_loss: 1.7596
# Epoch 6/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.3486 - loss: 1.7828 - val_accuracy: 0.3900 - val_loss: 1.7237
# Epoch 7/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.3546 - loss: 1.7634 - val_accuracy: 0.4084 - val_loss: 1.6904
# Epoch 8/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - accuracy: 0.3672 - loss: 1.7442 - val_accuracy: 0.4030 - val_loss: 1.7055
# Epoch 9/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - accuracy: 0.3695 - loss: 1.7331 - val_accuracy: 0.4212 - val_loss: 1.6675
# Epoch 10/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 25s 35ms/step - accuracy: 0.3747 - loss: 1.7196 - val_accuracy: 0.4020 - val_loss: 1.6827

# %%
layers.Conv2D(32, (3,3), activation='relu')
layers.Conv2D(64, (3,3), activation='relu')
layers.Conv2D(128,  (3,3), activation='relu')
# Out:
# <Conv2D name=conv2d_3, built=False>

# %%
cnn_model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(128, (3,3), activation='relu'),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(10, activation='softmax')
])

cnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

cnn_history_20 = cnn_model.fit(
    x_train_norm,
    y_train,
    epochs=20,
    validation_split=0.1,
    batch_size=64
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 94s 129ms/step - accuracy: 0.4700 - loss: 1.4878 - val_accuracy: 0.5150 - val_loss: 1.3197
# Epoch 2/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 140s 125ms/step - accuracy: 0.6065 - loss: 1.1288 - val_accuracy: 0.5704 - val_loss: 1.1929
# Epoch 3/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 90s 128ms/step - accuracy: 0.6680 - loss: 0.9577 - val_accuracy: 0.6272 - val_loss: 1.0653
# Epoch 4/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 139s 124ms/step - accuracy: 0.7111 - loss: 0.8325 - val_accuracy: 0.5966 - val_loss: 1.2434
# Epoch 5/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 143s 125ms/step - accuracy: 0.7414 - loss: 0.7349 - val_accuracy: 0.6038 - val_loss: 1.2892
# Epoch 6/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 89s 127ms/step - accuracy: 0.7674 - loss: 0.6655 - val_accuracy: 0.7120 - val_loss: 0.8632
# Epoch 7/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 141s 126ms/step - accuracy: 0.7958 - loss: 0.5881 - val_accuracy: 0.6582 - val_loss: 1.0539
# Epoch 8/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 143s 128ms/step - accuracy: 0.8150 - loss: 0.5259 - val_accuracy: 0.7174 - val_loss: 0.9102
# Epoch 9/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 88s 125ms/step - accuracy: 0.8285 - loss: 0.4831 - val_accuracy: 0.7340 - val_loss: 0.8175
# Epoch 10/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 141s 124ms/step - accuracy: 0.8472 - loss: 0.4336 - val_accuracy: 0.7082 - val_loss: 0.9590
# Epoch 11/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 88s 125ms/step - accuracy: 0.8588 - loss: 0.3951 - val_accuracy: 0.7316 - val_loss: 0.9656
# Epoch 12/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 141s 123ms/step - accuracy: 0.8695 - loss: 0.3655 - val_accuracy: 0.7316 - val_loss: 0.9892
# Epoch 13/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 88s 125ms/step - accuracy: 0.8835 - loss: 0.3288 - val_accuracy: 0.7348 - val_loss: 1.0080
# Epoch 14/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 88s 126ms/step - accuracy: 0.8878 - loss: 0.3155 - val_accuracy: 0.7128 - val_loss: 1.1921
# Epoch 15/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 88s 124ms/step - accuracy: 0.8989 - loss: 0.2857 - val_accuracy: 0.7400 - val_loss: 1.0046
# Epoch 16/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 88s 125ms/step - accuracy: 0.9032 - loss: 0.2670 - val_accuracy: 0.6976 - val_loss: 1.3375
# Epoch 17/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 142s 125ms/step - accuracy: 0.9093 - loss: 0.2567 - val_accuracy: 0.6044 - val_loss: 2.0448
# Epoch 18/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 89s 126ms/step - accuracy: 0.9139 - loss: 0.2426 - val_accuracy: 0.7394 - val_loss: 1.1568
# Epoch 19/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 87s 124ms/step - accuracy: 0.9176 - loss: 0.2343 - val_accuracy: 0.6984 - val_loss: 1.3448
# Epoch 20/20
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 142s 124ms/step - accuracy: 0.9207 - loss: 0.2234 - val_accuracy: 0.7302 - val_loss: 1.1709
